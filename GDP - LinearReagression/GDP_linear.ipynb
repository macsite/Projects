# %% [markdown]
# # Import data

# %%
import numpy as np
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("done succesfully")
# Out:
# done succesfully

# %%
data = pd.read_csv("C:/Users/macko/Desktop/pwc/case.csv")
print("done succesfully")
# Out:
# done succesfully

# %%
data
# Out:
#             y     x1    x2       x3    x4      x5
# 0         NaN  2.456  4.00  1386.96   6.4  406426
# 1    104.7474  2.837  4.04  1462.59   4.4  405948
# 2    104.8129  2.578  3.56  1736.47   4.6  405466
# 3    104.4135  2.793  3.13  1688.85  18.0  403957
# 4    104.4852  3.283  3.10  1822.57   4.4  400415
# ..        ...    ...   ...      ...   ...     ...
# 270   93.1620  0.896  6.15  2209.90  20.9  117295
# 271   92.8872  0.732  5.85  2391.20  14.7  116631
# 272   92.3118  0.857  6.05  1946.30  19.4  115932
# 273   91.9626  0.819  6.23  1852.90  37.9  115573
# 274   91.6261  0.695  6.63  1570.90  22.6  115232
#
# [275 rows x 6 columns]

# %%
data.x5[data.x5>390000]
# Out:
# 0    406426
# 1    405948
# 2    405466
# 3    403957
# 4    400415
# 5    394222
# Name: x5, dtype: int64

# %% [markdown]
# # Check and clean data

# %%
data.describe()
# Out:
#                 y          x1          x2           x3          x4  \
# count  274.000000  275.000000  275.000000   275.000000  275.000000
# mean    96.864250    1.775498    3.842655  2169.204364   18.167636
# std      4.975902    0.734485    1.219188   562.837890   10.934924
# min     84.727700    0.501000    1.270000  1017.800000  -18.600000
# 25%     92.801525    1.199500    2.895000  1780.335000   11.050000
# 50%     98.201700    1.702000    3.790000  2233.370000   18.900000
# 75%    101.001500    2.305000    4.850000  2438.665000   25.450000
# max    104.812900    4.049000    6.630000  3812.550000   41.200000
#
#                   x5
# count     275.000000
# mean   202433.625455
# std     62477.509237
# min    115232.000000
# 25%    152395.000000
# 50%    190174.000000
# 75%    243584.500000
# max    406426.000000

# %%
data.isnull().value_counts()
# Out:
# y      x1     x2     x3     x4     x5
# False  False  False  False  False  False    274
# True   False  False  False  False  False      1
# dtype: int64

# %%
data = data.iloc[1:]
data
# Out:
#             y     x1    x2       x3    x4      x5
# 1    104.7474  2.837  4.04  1462.59   4.4  405948
# 2    104.8129  2.578  3.56  1736.47   4.6  405466
# 3    104.4135  2.793  3.13  1688.85  18.0  403957
# 4    104.4852  3.283  3.10  1822.57   4.4  400415
# 5    103.9464  4.049  3.25  1824.05  11.7  394222
# ..        ...    ...   ...      ...   ...     ...
# 270   93.1620  0.896  6.15  2209.90  20.9  117295
# 271   92.8872  0.732  5.85  2391.20  14.7  116631
# 272   92.3118  0.857  6.05  1946.30  19.4  115932
# 273   91.9626  0.819  6.23  1852.90  37.9  115573
# 274   91.6261  0.695  6.63  1570.90  22.6  115232
#
# [274 rows x 6 columns]

# %% [markdown]
# # Check Correlations

# %%
heatmap_data = data.corr()
heatmap_data
# Out:
#            y        x1        x2        x3        x4        x5
# y   1.000000  0.515692 -0.515196  0.537522  0.446517  0.615794
# x1  0.515692  1.000000 -0.326310  0.595855  0.018548  0.296016
# x2 -0.515196 -0.326310  1.000000 -0.093061 -0.260306 -0.454749
# x3  0.537522  0.595855 -0.093061  1.000000  0.123368  0.276533
# x4  0.446517  0.018548 -0.260306  0.123368  1.000000  0.264020
# x5  0.615794  0.296016 -0.454749  0.276533  0.264020  1.000000

# %%
# dataframe[‘first_column’].corr(dataframe[‘second_column’])
data["y"].corr(data["x3"]*data["x5"])
# Out:
# 0.689893221566511

# %%
print("x1")
sns.boxplot(x=data.x1)
# Out:
# x1
# <AxesSubplot:xlabel='x1'>

# %%
sns.histplot(data.x1)
# Out:
# <AxesSubplot:xlabel='x1', ylabel='Count'>

# %%
print("x2")
sns.boxplot(x=data.x2)
# Out:
# x2
# <AxesSubplot:xlabel='x2'>

# %%
print("x3")
sns.boxplot(x=data.x3)
# Out:
# x3
# <AxesSubplot:xlabel='x3'>

# %%
print("x4")
sns.boxplot(x=data.x4)
# Out:
# x4
# <AxesSubplot:xlabel='x4'>

# %%
print("x5")
sns.boxplot(x=data.x5)
# Out:
# x5
# <AxesSubplot:xlabel='x5'>

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,7))

# Add title
plt.title("Correlation heatmap")

# Correlation heatmap
sns.heatmap(data=heatmap_data, annot=True, cmap=sns.diverging_palette(260, 17, center="light"))

# Add label for horizontal axis
# plt.xlabel("Airline")
# Out:
# <AxesSubplot:title={'center':'Correlation heatmap'}>

# %%
data.corr().abs()[["y"]]
# Out:
#            y
# y   1.000000
# x1  0.515692
# x2  0.515196
# x3  0.537522
# x4  0.446517
# x5  0.615794

# %%
sns.pairplot (data, kind="reg")

# %%
data
data.loc[:,["x1","x2","x3","x4","x5"]]
# Out:
#         x1    x2       x3    x4      x5
# 1    2.837  4.04  1462.59   4.4  405948
# 2    2.578  3.56  1736.47   4.6  405466
# 3    2.793  3.13  1688.85  18.0  403957
# 4    3.283  3.10  1822.57   4.4  400415
# 5    4.049  3.25  1824.05  11.7  394222
# ..     ...   ...      ...   ...     ...
# 270  0.896  6.15  2209.90  20.9  117295
# 271  0.732  5.85  2391.20  14.7  116631
# 272  0.857  6.05  1946.30  19.4  115932
# 273  0.819  6.23  1852.90  37.9  115573
# 274  0.695  6.63  1570.90  22.6  115232
#
# [274 rows x 5 columns]

# %% [markdown]
# # Create ML model

# %% [markdown]
# ## Linear Regression - feature X5

# %%
data[["x5"]]
# Out:
#          x5
# 1    405948
# 2    405466
# 3    403957
# 4    400415
# 5    394222
# ..      ...
# 270  117295
# 271  116631
# 272  115932
# 273  115573
# 274  115232
#
# [274 rows x 1 columns]

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, x_test, y_train, y_test = train_test_split(data.x5, data.y, test_size=0.2, random_state=0)
print("completed")
# Out:
# completed

# %%
data.plot(kind="scatter", x="x5", y="y")
plt.show()

# %%
plt.scatter(X_train, y_train, label="training data", color="b", alpha=0.7)
plt.scatter(x_test, y_test, label="testing data", color = "g", alpha=0.7)
plt.legend()
plt.title("test train split")
plt.show()

# %%
# Create linear model
LR = LinearRegression()
LR.fit(X_train.values.reshape(-1,1), y_train.values)
# Out:
# LinearRegression()

# %%
#  Make prediction
prediction = LR.predict(x_test.values.reshape(-1,1))
plt.plot(x_test, prediction, label="LinRegression", color="b")
plt.scatter(x_test, y_test, label="Actual test data", color = "g", alpha=0.7)
plt.legend()
plt.show()

# %%
#  predict value of specific x5

LR.predict(np.array([[239368]]))[0]
# Out:
# 98.66303193253142

# %%
X_train.values.reshape(-1,1)[4]
# Out:
# array([270222.])

# %% [markdown]
# ## Linear Regression for 2 dimensional problem - x3 * x5 ,  x1 * x5

# %%
data["x3x5"] = data["x3"] * data["x5"]
data["x1x5"] = data["x1"] * data["x5"]

data.plot(kind="scatter", x="x1x5", y="y")
plt.show()
# Out:
# C:\Users\macko\AppData\Local\Temp\ipykernel_4500\886804552.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["x3x5"] = data["x3"] * data["x5"]
# C:\Users\macko\AppData\Local\Temp\ipykernel_4500\886804552.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["x1x5"] = data["x1"] * data["x5"]

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, x_test, y_train, y_test = train_test_split(data.x3x5, data.y, test_size=0.2, random_state=0)
print("completed")

plt.scatter(X_train, y_train, label="training data", color="b", alpha=0.7)
plt.scatter(x_test, y_test, label="testing data", color = "g", alpha=0.7)
plt.legend()
plt.title("test train split")
plt.show()

# Create linear model
LR = LinearRegression()
LR.fit(X_train.values.reshape(-1,1), y_train.values)

#  Make prediction
prediction = LR.predict(x_test.values.reshape(-1,1))
plt.plot(x_test, prediction, label="LinRegression", color="b")
plt.scatter(x_test, y_test, label="Actual test data", color = "g", alpha=0.7)
plt.legend()
plt.show()

#  predict value of specific x5

LR.predict(np.array([[239368]]))[0]
# Out:
# completed
# 88.93689436380107

# %% [markdown]
# ## Linear Regression for multidimensional problem

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, x_test, y_train, y_test = train_test_split(data[["x1","x2","x3","x4","x5"]], data.y, test_size=0.2, random_state=0)
print("completed")
# Out:
# completed

# %%
# Create linear model
LR = LinearRegression()
LR.fit(X_train, y_train.values)
# Out:
# LinearRegression()

# %%
#  Make prediction
prediction = LR.predict(x_test)
# plt.plot(x_test, prediction, label="LinRegression", color="b")
# plt.scatter(x_test, y_test, label="Actual test data", color = "g", alpha=0.7)
# plt.legend()
# plt.show()

# %%
X_train
# Out:
#         x1    x2       x3    x4      x5
# 188  1.850  4.72  3549.33  27.0  270222
# 135  2.801  3.65  2813.35   8.9  139144
# 241  0.826  5.18  1118.59  16.4  145495
# 6    3.750  3.07  2164.81   9.6  385212
# 23   1.298  1.67  1556.14  23.8  267434
# ..     ...   ...      ...   ...     ...
# 252  0.501  5.12  1017.80   0.3  133088
# 193  1.510  4.85  2970.90  10.5  275661
# 118  2.669  3.08  2442.58   9.0  147645
# 48   1.546  3.36  2284.01  36.8  239368
# 173  3.284  4.69  2979.09   3.6  218522
#
# [219 rows x 5 columns]

# %%
#  predict value of specific x5

LR.predict(np.array([[1.546,3.36,2284.01,36.8,239368]]))[0]
# Out:
# c:\Users\macko\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 100.58394196683786
